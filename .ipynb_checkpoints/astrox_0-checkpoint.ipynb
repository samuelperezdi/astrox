# %% [markdown]
# ### UNSUPERVISED MACHINE LEARNING FOR THE CLASSIFICATION OF ASTROPHYSICAL X-RAY SOURCES

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
from astropy import stats
from astropy.io.votable import parse

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = (16, 16)
#plt.style.use('ggplot')

# %%
votable = parse("./data/corpus.vot")

# %%
def votable_to_pandas(votable_file):
    votable = parse(votable_file)
    table = votable.get_first_table().to_table(use_names_over_ids=True)
    return table.to_pandas()

# %%
data = votable_to_pandas("./data/corpus.vot")

# %% [markdown]
# #### Exploración

# %%
data.describe()
# Out:
#               obsid     region_id         theta            ra           dec  \
# count  37878.000000  37878.000000  37878.000000  37878.000000  37878.000000
# mean    7738.962062    383.943080      7.215788    154.484116     -1.713048
# std     4442.685154    840.636764      5.359062     96.174054     38.778529
# min       19.000000      1.000000      0.004970      0.012318    -85.645638
# 25%     4181.500000     25.000000      2.778966     83.763094    -29.053841
# 50%     7064.000000     96.000000      6.083105    160.982107     -5.355699
# 75%    11530.000000    312.000000     11.240255    228.306555     33.975893
# max    49899.000000   7213.000000     26.922311    359.997656     86.320337
#
#        significance     likelihood     src_area_b   flux_aper_b       hard_hm  \
# count  37878.000000   3.787800e+04   29752.000000  3.776100e+04  37344.000000
# mean      44.685588            inf     458.110004  7.113161e-13      0.064582
# std       64.438054            inf    3167.216755  5.771520e-12      0.360548
# min        0.000000   8.097478e+00       0.000037  0.000000e+00     -0.999375
# 25%       12.842973   5.664561e+02       0.394041  4.089393e-14     -0.119925
# 50%       21.569519   1.903882e+03       5.090457  9.094241e-14      0.058713
# 75%       48.664213   1.084745e+04      55.606112  2.870870e-13      0.227358
# max     1181.210704  1.797693e+308  143596.278780  5.414790e-10      0.999375
#
#        ...     ks_prob_h     ks_prob_m     ks_prob_s     kp_prob_b  \
# count  ...  33730.000000  35920.000000  3.363000e+04  37420.000000
# mean   ...      0.607855      0.594805  5.714102e-01      0.627788
# std    ...      0.318574      0.317466  3.140634e-01      0.325054
# min    ...      0.000035      0.000008  2.968807e-07      0.000023
# 25%    ...      0.335645      0.320623  2.962773e-01      0.346806
# 50%    ...      0.647459      0.628799  5.966723e-01      0.680281
# 75%    ...      0.918568      0.900790  8.652320e-01      0.956059
# max    ...      1.000000      1.000000  1.000000e+00      1.000000
#
#           kp_prob_h     kp_prob_m     kp_prob_s     gti_start      gti_stop  \
# count  33730.000000  35920.000000  33630.000000  3.787800e+04  3.787800e+04
# mean       0.603570      0.588157      0.565971  2.790502e+08  2.791110e+08
# std        0.319590      0.318298      0.313054  1.260029e+08  1.259975e+08
# min        0.000023      0.000025      0.000002  6.561709e+07  6.566766e+07
# 25%        0.328890      0.309782      0.295771  1.592887e+08  1.594554e+08
# 50%        0.641305      0.623832      0.584503  2.778035e+08  2.778564e+08
# 75%        0.918414      0.891419      0.857505  3.852647e+08  3.853960e+08
# max        1.000000      1.000000      1.000000  5.361096e+08  5.361516e+08
#
#           gti_elapse
# count   37878.000000
# mean    60807.276504
# std     47706.375641
# min       948.465970
# 25%     27452.799890
# 50%     48051.200045
# 75%     88428.799680
# max    192363.182400
#
# [8 rows x 45 columns]

# %%
data.head()
# Out:
#                     name  obsid  region_id      theta        ra        dec  \
# 0  2CXO J000002.9-350332  15712          4   5.606038  0.012318 -35.059068
# 1  2CXO J000010.0-501526  11997          5   7.662707  0.041803 -50.257400
# 2  2CXO J000019.8-245030  13394         69  14.525021  0.082814 -24.841752
# 3  2CXO J000025.4-245419  13394         41  11.145001  0.106246 -24.905300
# 4  2CXO J000027.4-500421  11997         43   5.944960  0.114303 -50.072669
#
#    significance   likelihood  src_area_b   flux_aper_b  ...  ks_prob_h  \
# 0     16.266113  1506.051665    6.228827  3.589425e-13  ...   0.724755
# 1     16.952246  1018.200194    8.978497  3.593006e-14  ...   0.249246
# 2     10.720911   351.465473  884.616067  1.002743e-13  ...   0.847319
# 3     16.716272   819.212066   39.749528  1.160466e-13  ...   0.067084
# 4     26.377284  3525.375052    3.925662  1.093804e-13  ...   0.969048
#
#    ks_prob_m  ks_prob_s  kp_prob_b  kp_prob_h  kp_prob_m  kp_prob_s  \
# 0   0.317516   0.423297   0.808309   0.669796   0.197852   0.691868
# 1   0.181138   0.805236   0.614278   0.101385   0.028956   0.918830
# 2   0.495847   0.506963   0.430789   0.817322   0.353208   0.778730
# 3   0.939628   0.368044   0.924866   0.051374   0.950423   0.288221
# 4   0.227237   0.030124   0.766089   0.932166   0.556750   0.047099
#
#       gti_start      gti_stop   gti_elapse
# 0  4.989492e+08  4.989593e+08  10068.80008
# 1  3.991763e+08  3.992403e+08  64051.80924
# 2  4.294139e+08  4.294639e+08  50055.70038
# 3  4.294139e+08  4.294639e+08  50055.70038
# 4  3.991763e+08  3.992403e+08  64051.80924
#
# [5 rows x 46 columns]

# %%
data.columns
# Out:
# Index(['name', 'obsid', 'region_id', 'theta', 'ra', 'dec', 'significance',
#        'likelihood', 'src_area_b', 'flux_aper_b', 'hard_hm', 'hard_hs',
#        'hard_ms', 'powlaw_gamma', 'bb_kt', 'var_prob_b', 'var_sigma_b',
#        'var_mean_b', 'var_min_b', 'var_max_b', 'var_prob_h', 'var_sigma_h',
#        'var_mean_h', 'var_min_h', 'var_max_h', 'var_prob_m', 'var_sigma_m',
#        'var_mean_m', 'var_min_m', 'var_max_m', 'var_prob_s', 'var_sigma_s',
#        'var_mean_s', 'var_min_s', 'var_max_s', 'ks_prob_b', 'ks_prob_h',
#        'ks_prob_m', 'ks_prob_s', 'kp_prob_b', 'kp_prob_h', 'kp_prob_m',
#        'kp_prob_s', 'gti_start', 'gti_stop', 'gti_elapse'],
#       dtype='object')

# %%
print(data.src_area_b.max())
print(data.bb_kt.max())
print(data.powlaw_gamma.max())
# Out:
# 143596.27878000482
# 999.751
# 10.0

# %%
x = StandardScaler().fit_transform(data.src_area_b)
plt.scatter(data.hard_hm,x)

#Labels and Tit
plt.title('hard_hm vs powlaw_gamma')
plt.xlabel('hard_hm')
plt.ylabel('powlaw_gamma')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-22b62bd01f25> in <module>
# ----> 1 x = StandardScaler().fit_transform(data.src_area_b)
#       2 plt.scatter(data.hard_hm,x)
#       3
#       4 #Labels and Tit
#       5 plt.title('hard_hm vs powlaw_gamma')
#
# NameError: name 'StandardScaler' is not defined

# %%
corr = data.corr()

fig, ax = plt.subplots(figsize=(16,16))   
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
features_coord = ['ra', 'dec','hard_hm','hard_hs', 'hard_ms','powlaw_gamma', 'var_prob_b', 'var_sigma_b',
       'var_mean_b', 'var_min_b', 'var_max_b', 'var_prob_h', 'var_sigma_h',
       'var_mean_h', 'var_min_h', 'var_max_h', 'var_prob_m', 'var_sigma_m',
       'var_mean_m', 'var_min_m', 'var_max_m', 'var_prob_s', 'var_sigma_s',
       'var_mean_s', 'var_min_s', 'var_max_s', 'ks_prob_b', 'ks_prob_h',
       'ks_prob_m', 'ks_prob_s', 'kp_prob_b', 'kp_prob_h', 'kp_prob_m',
       'kp_prob_s']

features = ['hard_hm','hard_hs', 'hard_ms', 'powlaw_gamma', 'var_prob_b', 'var_sigma_b',
       'var_mean_b', 'var_min_b', 'var_max_b', 'var_prob_h', 'var_sigma_h',
       'var_mean_h', 'var_min_h', 'var_max_h', 'var_prob_m', 'var_sigma_m',
       'var_mean_m', 'var_min_m', 'var_max_m', 'var_prob_s', 'var_sigma_s',
       'var_mean_s', 'var_min_s', 'var_max_s', 'ks_prob_b', 'ks_prob_h',
       'ks_prob_m', 'ks_prob_s', 'kp_prob_b', 'kp_prob_h', 'kp_prob_m',
       'kp_prob_s']

# %%
#sns.pairplot(data.dropna(),height=4,vars=features,kind='scatter')

# %% [markdown]
# #### K-Means

# %%
features_coord = ['ra', 'dec','hard_hm','hard_hs', 'hard_ms', 'var_prob_b', 'var_sigma_b',
            'var_prob_h', 'var_sigma_h',
        'var_prob_m', 'var_sigma_m', 'var_prob_s', 'var_sigma_s', 'ks_prob_b', 'ks_prob_h',
       'ks_prob_m', 'ks_prob_s', 'kp_prob_b', 'kp_prob_h', 'kp_prob_m',
       'kp_prob_s']

features = ['hard_hm','hard_hs', 'hard_ms', 'var_prob_b', 'var_sigma_b',
            'var_prob_h', 'var_sigma_h',
        'var_prob_m', 'var_sigma_m', 'var_prob_s', 'var_sigma_s', 'ks_prob_b', 'ks_prob_h',
       'ks_prob_m', 'ks_prob_s', 'kp_prob_b', 'kp_prob_h', 'kp_prob_m',
       'kp_prob_s']

X_df_coord = data[features_coord].dropna()
X_df = X_df_coord[features]
X = X_df.copy().to_numpy()

# %%
X_df.max()
# Out:
# hard_hm             0.995628
# hard_hs             0.999375
# hard_ms             0.999375
# var_prob_b          1.000000
# var_sigma_b      2461.558486
# var_prob_h          1.000000
# var_sigma_h     60181.108009
# var_prob_m          1.000000
# var_sigma_m    283478.539145
# var_prob_s          1.000000
# var_sigma_s    139016.635659
# ks_prob_b           1.000000
# ks_prob_h           1.000000
# ks_prob_m           1.000000
# ks_prob_s           1.000000
# kp_prob_b           1.000000
# kp_prob_h           1.000000
# kp_prob_m           1.000000
# kp_prob_s           1.000000
# dtype: float64

# %% [markdown]
# ### Aplicar logaritmo y luego normalización.

# %%
import pandas as pd
from sklearn import preprocessing

# Log transformation

x = np.log(X_df.var_sigma_b.values, where = X_df.var_sigma_b.values >0)  #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0,1))
x_scaled = min_max_scaler.fit_transform(x.reshape(-1,1))
X[:,4] = x_scaled.flatten()

x = np.log(X_df.var_sigma_h.values, where = X_df.var_sigma_h.values >0) #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0,1))
x_scaled = min_max_scaler.fit_transform(x.reshape(-1,1))
X[:,6] = x_scaled.flatten()

x = np.log(X_df.var_sigma_m.values, where = X_df.var_sigma_m.values >0) #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0,1))
x_scaled = min_max_scaler.fit_transform(x.reshape(-1,1))
X[:,8] = x_scaled.flatten()

x = np.log(X_df.var_sigma_s.values, where = X_df.var_sigma_s.values >0) #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0,1))
x_scaled = min_max_scaler.fit_transform(x.reshape(-1,1))
X[:,10] = x_scaled.flatten()



df = pd.DataFrame(X, columns=X_df.columns)

# %% [markdown]
# ## NOTA: Hablar con Rafael acerca de la transformación logarítmica en la variable sigma para los valores 0. ¿Añadir un valor pequeño, quitarlos, o dejar los ceros? Alex sugirió añadir un valor pequeño.

# %%
df = df.dropna()
X = df.to_numpy()

# %%
df
# Out:
#         hard_hm   hard_hs   hard_ms  var_prob_b  var_sigma_b  var_prob_h  \
# 0     -0.042473 -0.440974 -0.405996    0.067012     0.610208    0.113151
# 1     -0.049969 -0.277327 -0.229856    0.060476     0.575523    0.240287
# 2      0.041224 -0.278576 -0.311056    0.092881     0.618372    0.258846
# 3      0.033729 -0.329794 -0.358526    0.327994     0.654210    0.059139
# 4      0.154903 -0.126171 -0.276077    0.041535     0.584362    0.721471
# ...         ...       ...       ...         ...          ...         ...
# 29576 -0.187383 -0.608370 -0.474703    0.193192     0.647822    0.444792
# 29577  0.193629  0.296065  0.104934    0.069176     0.579229    0.166710
# 29578  0.084947 -0.262336 -0.338538    0.065255     0.600369    0.675261
# 29579  0.031230 -0.307308 -0.334791    0.069170     0.591068    0.377589
# 29580  0.163648 -0.049969 -0.212367    0.099865     0.627868    0.113808
#
#        var_sigma_h  var_prob_m  var_sigma_m  var_prob_s  var_sigma_s  \
# 0         0.599965    0.235485     0.636260    0.080282     0.585404
# 1         0.586303    0.074890     0.513389    0.408179     0.594170
# 2         0.604527    0.264466     0.603627    0.168614     0.584885
# 3         0.534663    0.650296     0.609193    0.082537     0.563817
# 4         0.623239    0.134520     0.559579    0.092223     0.540419
# ...            ...         ...          ...         ...          ...
# 29576     0.609654    0.598232     0.611797    0.357114     0.640213
# 29577     0.580630    0.778141     0.599035    0.320737     0.573346
# 29578     0.619597    0.352602     0.593824    0.322256     0.603171
# 29579     0.625143    0.149666     0.595850    0.105225     0.569502
# 29580     0.581353    0.118293     0.567219    0.584857     0.626326
#
#        ks_prob_b  ks_prob_h  ks_prob_m  ks_prob_s  kp_prob_b  kp_prob_h  \
# 0       0.491601   0.724755   0.317516   0.423297   0.808309   0.669796
# 1       0.441207   0.249246   0.181138   0.805236   0.614278   0.101385
# 2       0.798917   0.847319   0.495847   0.506963   0.430789   0.817322
# 3       0.932091   0.067084   0.939628   0.368044   0.924866   0.051374
# 4       0.816880   0.969048   0.227237   0.030124   0.766089   0.932166
# ...          ...        ...        ...        ...        ...        ...
# 29576   0.934161   0.583490   0.964677   0.262496   0.974790   0.494843
# 29577   0.249008   0.052800   0.338171   0.093817   0.447750   0.109237
# 29578   0.701624   0.691945   0.910468   0.948922   0.882940   0.727829
# 29579   0.535661   0.519522   0.711643   0.034164   0.683820   0.677194
# 29580   0.627601   0.480334   0.353657   0.987674   0.577222   0.595085
#
#        kp_prob_m  kp_prob_s
# 0       0.197852   0.691868
# 1       0.028956   0.918830
# 2       0.353208   0.778730
# 3       0.950423   0.288221
# 4       0.556750   0.047099
# ...          ...        ...
# 29576   0.989638   0.387899
# 29577   0.512777   0.100806
# 29578   0.955295   0.743982
# 29579   0.679284   0.162685
# 29580   0.148076   0.970533
#
# [29580 rows x 19 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from yellowbrick.cluster import KElbowVisualizer

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,8))

visualizer.fit(df)        # Fit the data to the visualizer
visualizer.show()
# Out:
# <img src="data:image/png;base64,..." width="720">
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans = KMeans(n_clusters=6).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[ 0.00474609 -0.20447167 -0.22645571  0.07908611  0.59042229  0.21737394
#    0.58146895  0.18482689  0.5664657   0.20098084  0.58178343  0.27645375
#    0.39163958  0.36809178  0.39155204  0.2697319   0.37985978  0.36211725
#    0.38396589]
#  [ 0.29024544  0.51821454  0.32435675  0.87610452  0.70108365  0.81226956
#    0.64627999  0.63462736  0.61017247  0.50143512  0.59300671  0.9838696
#    0.95816336  0.87638548  0.68945637  0.98492752  0.95442671  0.86617947
#    0.68808434]
#  [-0.03112367 -0.2427435  -0.23606784  0.15266772  0.61946258  0.336712
#    0.59695584  0.29275689  0.58386051  0.17687079  0.57616869  0.69932249
#    0.69626678  0.70661823  0.31839367  0.68946164  0.69228772  0.70639145
#    0.31558963]
#  [ 0.32082226  0.5165977   0.26784148  0.09745905  0.60540867  0.15929349
#    0.57962915  0.20637275  0.57252153  0.3490557   0.5909027   0.52607615
#    0.51943646  0.49326235  0.52892487  0.51744632  0.52169541  0.48179792
#    0.52273488]
#  [-0.0738273  -0.31689825 -0.28403147  0.19112919  0.62678567  0.28688409
#    0.58892708  0.22919135  0.57386648  0.32008154  0.60086151  0.76260957
#    0.54066541  0.56198952  0.79966865  0.75709685  0.53841487  0.5524052
#    0.79169576]
#  [-0.17751175 -0.44585341 -0.33052445  0.95038     0.70463723  0.81658859
#    0.62997073  0.82538537  0.62469832  0.70795441  0.62847061  0.99325608
#    0.92739021  0.9611718   0.92231703  0.9951637   0.926347    0.95860858
#    0.91702221]]

# %%
kmeans.n_iter_
# Out:
# 29

# %%
# %matplotlib notebook
plt.rcParams['figure.figsize'] = (10, 10)
plt.style.use('ggplot')

colx = 0
coly = 1
colz = 4
# Predicting the clusters
labels = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_
colores=['red','blue', 'green', 'black', 'cyan', 'purple']
asignar=[]
for row in labels:
    asignar.append(colores[row])

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 4], c=asignar,s=20)
ax.scatter(C[:, 0], C[:, 1], C[:, 4], marker='*', c=colores, s=1000)
ax.set(xlabel = df.columns[colx])
ax.set(ylabel = df.columns[coly])
ax.set(zlabel = df.columns[colz])
# Out:
# <img src="data:image/png;base64,..." width="720">
# [Text(0.5, 0, 'var_sigma_b')]

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 10)
plt.style.use('ggplot')

# %%
colx = 2
coly = 9
fig = plt.figure()
plt.scatter(X[:, colx], X[:, coly], c=asignar,s=20)
plt.scatter(C[:, colx], C[:, coly], marker='*', c=colores, s=1000)
plt.xlabel(df.columns[colx]);
plt.ylabel(df.columns[coly]);
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# # NOTA: Pairplot con todos.

# %%
colx = df.columns.get_loc("hard_hm")
coly = df.columns.get_loc("ks_prob_h")
fig = plt.figure()
plt.scatter(X[:, colx], X[:, coly], c=asignar,s=20)
plt.scatter(C[:, colx], C[:, coly], marker='*', c=colores, s=1000)
plt.xlabel(df.columns[colx]);
plt.ylabel(df.columns[coly]);

# %%
colx = df.columns.get_loc("hard_hs")
coly = df.columns.get_loc("kp_prob_h")
fig = plt.figure()
plt.scatter(X[:, colx], X[:, coly], c=asignar,s=20)
plt.scatter(C[:, colx], C[:, coly], marker='*', c=colores, s=1000)
plt.xlabel(df.columns[colx]);
plt.ylabel(df.columns[coly]);

# %%
colx = df.columns.get_loc("hard_hm")
coly = df.columns.get_loc("hard_hs")
fig = plt.figure()
plt.scatter(X[:, colx], X[:, coly], c=asignar,s=20)
plt.scatter(C[:, colx], C[:, coly], marker='*', c=colores, s=1000)
plt.xlabel(df.columns[colx]);
plt.ylabel(df.columns[coly]);

# %%
colx = df.columns.get_loc("hard_hm")
coly = df.columns.get_loc("var_sigma_b")
fig = plt.figure()
plt.scatter(X[:, colx], X[:, coly], c=asignar,s=20)
plt.scatter(C[:, colx], C[:, coly], marker='*', c=colores, s=1000)
plt.xlabel(df.columns[colx]);
plt.ylabel(df.columns[coly]);

# %%
xd=X_df_coord.to_numpy()

fig = plt.figure()
plt.scatter(xd[:, 0], xd[:, 1], c=asignar,s=20)
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# #### NOTA: Ver diferencias entre los centroides.
